# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel-rojas18/Talleres-POO/blob/main/Simulador_SVM_Precios_de_Vivienda_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://simulador-svm-precios-de-vivienda-usa-1.ai.studio

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
